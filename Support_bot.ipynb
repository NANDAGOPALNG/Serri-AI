# %% [markdown]
# # 🤖 Customer Support Bot with Document Training & Feedback Loop for Serri AI
#
# This notebook demonstrates the step-by-step development of an **AI-powered Customer Support Bot**.
# The bot is trained on a sample FAQ document, uses NLP models to answer queries, and improves responses through a feedback loop.
# Finally, we deploy the bot using **Gradio** for interactive use.
#
# ### Workflow Steps:
# 1. **Environment Setup** – Install required libraries.
# 2. **Imports & Logging** – Load dependencies and configure logging.
# 3. **Bot Class Definition** – Implement `SupportBotAgent` with document ingestion, retrieval, QA, and feedback handling.
# 4. **Initialize the Bot** – Load the FAQ and prepare embeddings.
# 5. **Testing Queries** – Run sample queries with feedback loop.
# 6. **Deploy Gradio Interface** – Build an interactive UI for deployment.

# %% [markdown]
# ## 📦 Install Required Packages
# We start by installing the required libraries for the project, including **ipywidgets** for notebook interactivity.

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipywidgets) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in c:\users\nanda\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\nanda\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install **Sentence Transformers** for semantic embeddings and document retrieval.

# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Using cached sentence_transformers-5.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sentence_transformers) (4.56.1)
# Requirement already satisfied: tqdm in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sentence_transformers) (2.8.0)
# Collecting scikit-learn (from sentence_transformers)
#   Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers)
#   Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sentence_transformers) (0.34.4)
# Collecting Pillow (from sentence_transformers)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sentence_transformers) (4.14.0)
# Requirement already satisfied: filelock in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\nanda\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\nanda\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence_transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\nanda\appdata\roaming\python\python313\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.4.26)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence_transformers)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence_transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached sentence_transformers-5.1.1-py3-none-any.whl (486 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/7.0 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.0 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.0/7.0 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.0 MB 1.5 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/7.0 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.0 MB 1.3 MB/s eta 0:00:04
#    --------------- ------------------------ 2.6/7.0 MB 1.6 MB/s eta 0:00:03
#    ------------------ --------------------- 3.1/7.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 4.2/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/7.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 2.7 MB/s  0:00:02
# Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.7 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.7 MB 6.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.7 MB 5.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.7 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.7 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.7 MB 4.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 4.8 MB/s  0:00:01
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.5 MB 5.8 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/38.5 MB 5.4 MB/s eta 0:00:07
#    --- ------------------------------------ 3.1/38.5 MB 4.9 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.5/38.5 MB 5.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.5/38.5 MB 5.2 MB/s eta 0:00:07
#    ------ --------------------------------- 6.6/38.5 MB 5.1 MB/s eta 0:00:07
#    -------- ------------------------------- 7.9/38.5 MB 5.2 MB/s eta 0:00:06
#    -------- ------------------------------- 8.1/38.5 MB 5.3 MB/s eta 0:00:06
#    --------- ------------------------------ 9.4/38.5 MB 4.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.5/38.5 MB 4.8 MB/s eta 0:00:06
#    ------------ --------------------------- 11.8/38.5 MB 5.0 MB/s eta 0:00:06
#    ------------- -------------------------- 13.1/38.5 MB 5.0 MB/s eta 0:00:06
#    -------------- ------------------------- 14.4/38.5 MB 5.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 15.5/38.5 MB 5.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 16.5/38.5 MB 5.1 MB/s eta 0:00:05
#    ------------------ --------------------- 17.8/38.5 MB 5.1 MB/s eta 0:00:05
#    ------------------- -------------------- 19.1/38.5 MB 5.2 MB/s eta 0:00:04
#    --------------------- ------------------ 20.4/38.5 MB 5.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 21.8/38.5 MB 5.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.8/38.5 MB 5.3 MB/s eta 0:00:03
#    ------------------------ --------------- 23.9/38.5 MB 5.2 MB/s eta 0:00:03
#    ------------------------- -------------- 24.9/38.5 MB 5.2 MB/s eta 0:00:03
#    -------------------------- ------------- 25.7/38.5 MB 5.1 MB/s eta 0:00:03
#    --------------------------- ------------ 26.2/38.5 MB 5.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.0/38.5 MB 5.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.0/38.5 MB 5.0 MB/s eta 0:00:03
#    ------------------------------ --------- 29.4/38.5 MB 5.0 MB/s eta 0:00:02
#    ------------------------------- -------- 30.7/38.5 MB 5.1 MB/s eta 0:00:02
#    --------------------------------- ------ 32.0/38.5 MB 5.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.5 MB 5.1 MB/s eta 0:00:02
#    ------------------------------------ --- 34.9/38.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.5 MB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 5.0 MB/s  0:00:07
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, Pillow, joblib, scikit-learn, sentence_transformers
#
#    ---------------------------------------- 0/6 [threadpoolctl]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    ------------- -------------------------- 2/6 [Pillow]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------- ------------------- 3/6 [joblib]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    --------------------------------- ------ 5/6 [sentence_transformers]
#    ---------------------------------------- 6/6 [sentence_transformers]
#
# Successfully installed Pillow-11.3.0 joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.2 sentence_transformers-5.1.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install **Gradio** for building a web-based user interface to interact with the bot.

# %%
pip install gradio
# Out:
# Collecting gradio
#   Using cached gradio-5.47.2-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from gradio) (4.10.0)
# Collecting audioop-lts<1.0 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Using cached fastapi-0.118.0-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Using cached ffmpy-0.6.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.13.3 (from gradio)
#   Using cached gradio_client-1.13.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Using cached groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (2.3.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from gradio) (2.3.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from gradio) (11.3.0)
# Collecting pydantic<2.12,>=2.0 (from gradio)
#   Using cached pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting pydub (from gradio)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Using cached ruff-0.13.2-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Using cached safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Using cached starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Using cached tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Using cached typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio) (4.14.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Using cached uvicorn-0.37.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in c:\users\nanda\appdata\roaming\python\python313\site-packages (from gradio-client==1.13.3->gradio) (2025.9.0)
# Collecting websockets<16.0,>=13.0 (from gradio-client==1.13.3->gradio)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\nanda\appdata\roaming\python\python313\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\nanda\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.19.1)
# Requirement already satisfied: requests in c:\users\nanda\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<2.12,>=2.0->gradio)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Using cached rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\nanda\appdata\roaming\python\python313\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nanda\onedrive\desktop\serri_chatbot\env\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nanda\appdata\roaming\python\python313\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.4.0)
# Using cached gradio-5.47.2-py3-none-any.whl (60.4 MB)
# Using cached gradio_client-1.13.3-py3-none-any.whl (325 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Using cached fastapi-0.118.0-py3-none-any.whl (97 kB)
# Using cached groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl (131 kB)
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 812.7 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/2.0 MB 938.4 kB/s eta 0:00:02
#    --------------------- ------------------ 1.0/2.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.3 MB/s  0:00:02
# Using cached safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached starlette-0.48.0-py3-none-any.whl (73 kB)
# Using cached tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Using cached typer-0.19.2-py3-none-any.whl (46 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl (358 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached rich-14.1.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached ruff-0.13.2-py3-none-win_amd64.whl (13.3 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached uvicorn-0.37.0-py3-none-any.whl (67 kB)
# Using cached ffmpy-0.6.1-py3-none-any.whl (5.5 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, brotli, websockets, typing-inspection, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, orjson, mdurl, groovy, ffmpy, audioop-lts, annotated-types, aiofiles, uvicorn, starlette, pydantic, markdown-it-py, safehttpx, rich, gradio-client, fastapi, typer, gradio
#
#    ----------------------------------------  0/27 [pydub]
#    ----------------------------------------  0/27 [pydub]
#    ----------------------------------------  0/27 [pydub]
#    - --------------------------------------  1/27 [brotli]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    ---- -----------------------------------  3/27 [typing-inspection]
#    ----- ----------------------------------  4/27 [tomlkit]
#    ----- ----------------------------------  4/27 [tomlkit]
#    ----- ----------------------------------  4/27 [tomlkit]
#    ----- ----------------------------------  4/27 [tomlkit]
#    ----- ----------------------------------  4/27 [tomlkit]
#    ------- --------------------------------  5/27 [shellingham]
#    ------- --------------------------------  5/27 [shellingham]
#    -------- -------------------------------  6/27 [semantic-version]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ---------- -----------------------------  7/27 [ruff]
#    ----------- ----------------------------  8/27 [python-multipart]
#    ----------- ----------------------------  8/27 [python-multipart]
#    ------------- --------------------------  9/27 [pydantic-core]
#    ------------- --------------------------  9/27 [pydantic-core]
#    ------------- --------------------------  9/27 [pydantic-core]
#    ---------------- ----------------------- 11/27 [mdurl]
#    ---------------- ----------------------- 11/27 [mdurl]
#    ----------------- ---------------------- 12/27 [groovy]
#    ------------------- -------------------- 13/27 [ffmpy]
#    ---------------------- ----------------- 15/27 [annotated-types]
#    ----------------------- ---------------- 16/27 [aiofiles]
#    ----------------------- ---------------- 16/27 [aiofiles]
#    ----------------------- ---------------- 16/27 [aiofiles]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    ------------------------- -------------- 17/27 [uvicorn]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    -------------------------- ------------- 18/27 [starlette]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ---------------------------- ----------- 19/27 [pydantic]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [markdown-it-py]
#    ------------------------------- -------- 21/27 [safehttpx]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    ---------------------------------- ----- 23/27 [gradio-client]
#    ---------------------------------- ----- 23/27 [gradio-client]
#    ---------------------------------- ----- 23/27 [gradio-client]
#    ---------------------------------- ----- 23/27 [gradio-client]
#    ---------------------------------- ----- 23/27 [gradio-client]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ----------------------------------- ---- 24/27 [fastapi]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    ------------------------------------- -- 25/27 [typer]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    -------------------------------------- - 26/27 [gradio]
#    ---------------------------------------- 27/27 [gradio]
#
# Successfully installed aiofiles-24.1.0 annotated-types-0.7.0 audioop-lts-0.2.2 brotli-1.1.0 fastapi-0.118.0 ffmpy-0.6.1 gradio-5.47.2 gradio-client-1.13.3 groovy-0.1.2 markdown-it-py-4.0.0 mdurl-0.1.2 orjson-3.11.3 pydantic-2.11.9 pydantic-core-2.33.2 pydub-0.25.1 python-multipart-0.0.20 rich-14.1.0 ruff-0.13.2 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.48.0 tomlkit-0.13.3 typer-0.19.2 typing-inspection-0.4.1 uvicorn-0.37.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 🛠 Import Libraries & Configure Environment
# Here we import the required libraries:
# - `transformers` for question-answering,
# - `sentence-transformers` for semantic search,
# - `torch` for backend,
# - `gradio` for UI,
# and configure logging with timestamps.

# %%
import logging
import random
import torch
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
import gradio as gr
from datetime import datetime

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
# Out:
# PyTorch Version: 2.8.0+cpu
# CUDA Available: False

# %% [markdown]
# ## 📑 Setup Logging
# We configure logging to save all important actions, queries, and feedback into `support_bot_log.txt`.

# %%
# Setup logging
logging.basicConfig(
    filename='support_bot_log.txt',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %% [markdown]
# ## 🤖 Define the SupportBotAgent Class
# This class implements the entire workflow:
# - **Document loading** (TXT/FAQ file)
# - **Semantic search** using embeddings
# - **Answer generation** using QA model
# - **Feedback simulation** and iterative improvement (max 2 iterations)
# - **Logging** of all decisions and actions

# %%
class SupportBotAgent:
    """
    Intelligent Customer Support Bot with document training and feedback loop
    """
    
    def __init__(self, document_path):
        """Initialize the bot with document and models"""
        print("🤖 Initializing Support Bot...")
        
        # Load NLP models
        print("📥 Loading question-answering model...")
        self.qa_model = pipeline(
            "question-answering",
            model="distilbert-base-uncased-distilled-squad"
        )
        
        print("📥 Loading sentence embedding model...")
        self.embedder = SentenceTransformer('all-MiniLM-L6-v2')
        
        # Load and process document
        print(f"📄 Loading document: {document_path}")
        self.document_text = self.load_document(document_path)
        
        # Split into sections
        self.sections = [s.strip() for s in self.document_text.split('\n\n') if s.strip()]
        print(f"✂️  Document split into {len(self.sections)} sections")
        
        # Create embeddings
        print("🧮 Creating embeddings...")
        self.section_embeddings = self.embedder.encode(
            self.sections,
            convert_to_tensor=True
        )
        
        logging.info(f"Loaded document: {document_path} with {len(self.sections)} sections")
        print("✅ Bot initialized successfully!\n")
    
    def load_document(self, path):
        """Load document from file"""
        try:
            with open(path, 'r', encoding='utf-8') as file:
                text = file.read()
            return text
        except FileNotFoundError:
            logging.error(f"Document not found: {path}")
            return ""
        except Exception as e:
            logging.error(f"Error loading document: {str(e)}")
            return ""
    
    def find_relevant_section(self, query):
        """Find most relevant section using semantic search"""
        if not self.sections:
            return None
        
        query_embedding = self.embedder.encode(query, convert_to_tensor=True)
        similarities = util.cos_sim(query_embedding, self.section_embeddings)[0]
        best_idx = similarities.argmax().item()
        best_score = similarities[best_idx].item()
        
        logging.info(f"Query: '{query}' | Best match score: {best_score:.3f}")
        
        # Threshold for relevance
        if best_score < 0.3:
            logging.warning(f"Low relevance score for query: {query}")
            return None
        
        return self.sections[best_idx]
    
    def answer_query(self, query, iteration=0):
        """Generate answer for query"""
        context = self.find_relevant_section(query)
        
        if not context:
            response = "I don't have enough information to answer that question. Please contact our support team at support@example.com or call 1-800-555-1234."
            logging.info(f"No relevant context found for: {query}")
            return response
        
        try:
            result = self.qa_model(question=query, context=context)
            answer = result["answer"]
            confidence = result["score"]
            
            logging.info(f"Generated answer (confidence: {confidence:.3f}): {answer}")
            return answer
        except Exception as e:
            logging.error(f"Error generating answer: {str(e)}")
            return "I encountered an error processing your question. Please try rephrasing it."
    
    def get_feedback(self, response):
        """Simulate user feedback"""
        # Simulate realistic feedback distribution
        feedback = random.choices(
            ["not helpful", "too vague", "good"],
            weights=[0.2, 0.3, 0.5]  # 50% good, 30% vague, 20% not helpful
        )[0]
        
        logging.info(f"Feedback received: {feedback}")
        return feedback
    
    def adjust_response(self, query, response, feedback):
        """Adjust response based on feedback"""
        logging.info(f"Adjusting response based on feedback: {feedback}")
        
        if feedback == "too vague":
            # Add more context
            context = self.find_relevant_section(query)
            if context:
                adjusted = f"{response}\n\nAdditional context: {context[:200]}..."
                logging.info("Added context to response")
                return adjusted
        
        elif feedback == "not helpful":
            # Try rephrasing the query
            rephrased_query = f"{query} Please provide more details."
            adjusted = self.answer_query(rephrased_query, iteration=1)
            logging.info(f"Rephrased query: {rephrased_query}")
            return adjusted
        
        return response
    
    def process_query_with_feedback(self, query):
        """Process query with feedback loop (max 2 iterations)"""
        logging.info(f"\n{'='*60}")
        logging.info(f"NEW QUERY: {query}")
        logging.info(f"{'='*60}")
        
        # Initial response
        response = self.answer_query(query)
        history = [f"**Initial Response:** {response}"]
        
        # Feedback loop (max 2 iterations)
        for iteration in range(2):
            feedback = self.get_feedback(response)
            
            if feedback == "good":
                history.append(f"\n**Feedback {iteration + 1}:** ✅ Good - Response accepted")
                break
            
            history.append(f"\n**Feedback {iteration + 1}:** ⚠️ {feedback.title()}")
            response = self.adjust_response(query, response, feedback)
            history.append(f"**Adjusted Response:** {response}")
        
        return "\n".join(history)
    
    def chat(self, query):
        """Simple chat interface without feedback simulation"""
        if not query.strip():
            return "Please enter a question."
        
        logging.info(f"Chat query: {query}")
        response = self.answer_query(query)
        return response

print("✅ SupportBotAgent class defined!")
# Out:
# ✅ SupportBotAgent class defined!

# %% [markdown]
# ## 🚀 Initialize the Bot
# We create an instance of `SupportBotAgent` and load the sample FAQ document (`faq.txt`).

# %%
# Initialize the bot
bot = SupportBotAgent("faq.txt")
# Out:
# 🤖 Initializing Support Bot...
# 📥 Loading question-answering model...
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Device set to use cpu
# 📥 Loading sentence embedding model...
# 📄 Loading document: faq.txt
# ✂️  Document split into 10 sections
# 🧮 Creating embeddings...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Bot initialized successfully!

# %% [markdown]
# ## 🧪 Test the Bot with Sample Queries
# We run a few example queries (e.g., password reset, refund policy, out-of-scope queries) and observe how the bot handles feedback and adjusts its responses.

# %%
# Test queries
test_queries = [
    "How do I reset my password?",
    "What's the refund policy?",
    "How do I contact support?",
    "What are the shipping options?",
    "How do I fly to the moon?"  # Out-of-scope
]

print("🧪 Testing bot with sample queries...\n")
for query in test_queries:
    print(f"\n{'='*70}")
    print(f"Query: {query}")
    print(f"{'='*70}")
    result = bot.process_query_with_feedback(query)
    print(result)
    print()
# Out:
# 🧪 Testing bot with sample queries...
#
#
# ======================================================================
# Query: How do I reset my password?
# ======================================================================
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# **Initial Response:** go to the login page
#
# **Feedback 1:** ⚠️ Too Vague
# **Adjusted Response:** go to the login page
#
# Additional context: Resetting Your Password
# To reset your password, go to the login page and click "Forgot Password."
# Enter your email address and follow the link sent to your inbox.
# If you don't receive the email with...
#
# **Feedback 2:** ✅ Good - Response accepted
#
#
# ======================================================================
# Query: What's the refund policy?
# ======================================================================
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# **Initial Response:** We offer full refunds within 30 days of purchase
#
# **Feedback 1:** ✅ Good - Response accepted
#
#
# ======================================================================
# Query: How do I contact support?
# ======================================================================
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# **Initial Response:** Email us at support@example.com
#
# **Feedback 1:** ✅ Good - Response accepted
#
#
# ======================================================================
# Query: What are the shipping options?
# ======================================================================
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# **Initial Response:** free for orders over $50
#
# **Feedback 1:** ✅ Good - Response accepted
#
#
# ======================================================================
# Query: How do I fly to the moon?
# ======================================================================
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# **Initial Response:** I don't have enough information to answer that question. Please contact our support team at support@example.com or call 1-800-555-1234.
#
# **Feedback 1:** ⚠️ Not Helpful
# **Adjusted Response:** I don't have enough information to answer that question. Please contact our support team at support@example.com or call 1-800-555-1234.
#
# **Feedback 2:** ⚠️ Too Vague
# **Adjusted Response:** I don't have enough information to answer that question. Please contact our support team at support@example.com or call 1-800-555-1234.

# %% [markdown]
# ## 🌐 Create Gradio Interface for Deployment
# Here we build a Gradio interface with three tabs:
# - **Chat**: Ask questions and get answers directly.
# - **Feedback Simulation**: See how responses improve with simulated feedback.
# - **About**: Information about the bot and its features.
#
# Finally, we launch the Gradio demo and generate a shareable public link.

# %%
# Create Gradio Interface
def create_gradio_interface():
    """Create Gradio UI for the bot"""
    
    # Custom CSS
    custom_css = """
    .gradio-container {
        font-family: 'Arial', sans-serif;
    }
    .header {
        text-align: center;
        padding: 20px;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        border-radius: 10px;
        margin-bottom: 20px;
    }
    """
    
    with gr.Blocks(css=custom_css, theme=gr.themes.Soft()) as demo:
        
        gr.Markdown(
            """
            <div class="header">
                <h1>🤖 AI Customer Support Bot</h1>
                <p>Ask me anything about our services, policies, and support!</p>
            </div>
            """
        )
        
        with gr.Tab("💬 Chat"):
            gr.Markdown("### Ask your question and get instant answers!")
            
            with gr.Row():
                with gr.Column(scale=2):
                    query_input = gr.Textbox(
                        label="Your Question",
                        placeholder="e.g., How do I reset my password?",
                        lines=2
                    )
                    
                    with gr.Row():
                        submit_btn = gr.Button("Ask Question", variant="primary", size="lg")
                        clear_btn = gr.Button("Clear", size="lg")
                    
                    # Example queries
                    gr.Examples(
                        examples=[
                            "How do I reset my password?",
                            "What is your refund policy?",
                            "How can I contact support?",
                            "What are the shipping options?",
                            "How do I track my order?",
                            "What payment methods do you accept?"
                        ],
                        inputs=query_input,
                        label="Try these example questions:"
                    )
                
                with gr.Column(scale=3):
                    response_output = gr.Textbox(
                        label="Bot Response",
                        lines=10,
                        interactive=False
                    )
        
        with gr.Tab("🔄 Feedback Simulation"):
            gr.Markdown("### See how the bot improves responses with simulated feedback!")
            
            query_feedback = gr.Textbox(
                label="Your Question",
                placeholder="e.g., What's the refund policy?",
                lines=2
            )
            
            feedback_btn = gr.Button("Process with Feedback Loop", variant="primary", size="lg")
            
            feedback_output = gr.Textbox(
                label="Response with Feedback Iterations",
                lines=15,
                interactive=False
            )
        
        with gr.Tab("📊 About"):
            gr.Markdown(
                """
                ## About This Bot
                
                This intelligent customer support bot uses:
                
                - **📄 Document Training**: Trained on company FAQ documents
                - **🧠 NLP Models**: 
                  - `distilbert-base-uncased-distilled-squad` for question answering
                  - `all-MiniLM-L6-v2` for semantic search
                - **🔍 Semantic Search**: Finds relevant information using embeddings
                - **🔄 Feedback Loop**: Improves responses based on simulated feedback
                - **📝 Logging**: Tracks all decisions and actions
                
                ### Features
                - ✅ Accurate answers from trained documents
                - ✅ Handles out-of-scope queries gracefully
                - ✅ Iterative improvement with feedback
                - ✅ Transparent decision logging
                
                ### Technology Stack
                - Python 3.8+
                - Transformers (Hugging Face)
                - Sentence Transformers
                - Gradio
                
                ---
                
                **Note**: This is a demo bot. For real support, contact support@example.com
                """
            )
        
        # Event handlers
        submit_btn.click(
            fn=bot.chat,
            inputs=query_input,
            outputs=response_output
        )
        
        feedback_btn.click(
            fn=bot.process_query_with_feedback,
            inputs=query_feedback,
            outputs=feedback_output
        )
        
        clear_btn.click(
            lambda: ("", ""),
            outputs=[query_input, response_output]
        )
    
    return demo

# Create and launch interface
demo = create_gradio_interface()
demo.launch(share=True)  # share=True creates public link
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://20cb0f43be758f7ebf.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://20cb0f43be758f7ebf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
